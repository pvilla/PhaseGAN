# %%
"""
Run PhaseGAN with Colab Notebooks
Go to Edit -> Notebook settings -> Hardware accelerator, select GPU, this will allow you run on GPU. Use the following command to check the GPU info (Shift + Enter / Ctrl + Enter).

"""
gpu_info = !nvidia-smi
gpu_info = '\n'.join(gpu_info)
if gpu_info.find('failed') >= 0:
  print('Select the Runtime → "Change runtime type" menu to enable a GPU accelerator, ')
  print('and then re-execute this cell.')
else:
  print(gpu_info)
from psutil import virtual_memory
ram_gb = virtual_memory().total / 1e9
print('Your runtime has {:.1f} gigabytes of available RAM\n'.format(ram_gb))
# Out:
# Fri Jul  3 15:45:50 2020
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 450.36.06    Driver Version: 418.67       CUDA Version: 10.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla K80           Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   30C    P8    29W / 149W |      0MiB / 11441MiB |      0%      Default |
# |                               |                      |                 ERR! |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
"""
Mount to your Google Drive directory (Optional)
You will need to login to your Google account and enter the authorization code
"""

from google.colab import drive
drive.mount('/content/drive')
import os
cwd = "./drive/My Drive/Colab Notebooks/tutorial_PhaseGAN" # change to your directory
os.chdir( "./drive/My Drive/Colab Notebooks/tutorial_PhaseGAN")

# %%
# !git clone https://github.com/pvilla/PhaseGAN.git
# Out:
# Cloning into 'PhaseGAN'...
# remote: Enumerating objects: 68, done.
# remote: Counting objects: 100% (68/68), done.
# remote: Compressing objects: 100% (66/66), done.
# remote: Total 68 (delta 25), reused 0 (delta 0), pack-reused 0
# Unpacking objects: 100% (68/68), done.

# %%
os.chdir('PhaseGAN/')
# !pip install -r requirements.txt

# %%
# !python3 train.py --help
# Out:
# usage: train.py [-h] [--load_path LOAD_PATH] [--run_path RUN_PATH]
#                 [--run_name RUN_NAME] [--batch_size BATCH_SIZE]
#                 [--lambda_GA LAMBDA_GA] [--lambda_GB LAMBDA_GB]
#                 [--lambda_FSCA LAMBDA_FSCA] [--lambda_FSCB LAMBDA_FSCB]
#                 [--lambda_A LAMBDA_A] [--lambda_B LAMBDA_B] [--no_pretrain]
#                 [--isTest] [--lr_g LR_G] [--lr_d LR_D]
#                 [--num_epochs NUM_EPOCHS] [--beta1 BETA1]
#                 [--clip_max CLIP_MAX] [--image_stats IMAGE_STATS]
#                 [--energy ENERGY] [--pxs PXS] [--z Z]
#                 [--adjust_lr_epoch ADJUST_LR_EPOCH] [--log_note LOG_NOTE]
#                 [--save_model_freq_epoch SAVE_MODEL_FREQ_EPOCH]
#                 [--print_loss_freq_iter PRINT_LOSS_FREQ_ITER]
#                 [--save_cycleplot_freq_iter SAVE_CYCLEPLOT_FREQ_ITER]
#                 [--save_val_freq_epoch SAVE_VAL_FREQ_EPOCH]
#
# optional arguments:
# ...

# %% [markdown]
# Training example (results will be saved to ./results/fig)

# %%
# !python3 train.py --run_name 'test' --num_epochs 50 --print_loss_freq_iter 20  --save_cycleplot_freq_iter 200 --load_path "/content/drive/My Drive/Colab Notebooks/tutorial_PhaseGAN/example_dataset"
# Change path to the data directory. An example dataset is available at https://drive.google.com/drive/folders/1rKTZYJa54WeG-2TikoXpdRcqTiSQ-Ps5?usp=sharing
# Out:
# device:cuda:0
# start loading data....
# finish loading data
# /pytorch/aten/src/ATen/native/BinaryOps.cpp:81: UserWarning: Integer division of tensors using div or / is deprecated, and in a future release div will perform true division as in Python 3. Use true_divide or floor_divide (// in Python) instead.
# Epoch [1/50], Step [20/1000], D_A: 0.533, G_A: 0.842, cycle_A: 15.600, D_B: 0.335, G_B: 2.310, cycle_B: 18.731, fscA: 2.059, fscB: 2.872
# Epoch [1/50], Step [40/1000], D_A: 0.445, G_A: 1.108, cycle_A: 10.873, D_B: 0.569, G_B: 0.915, cycle_B: 18.433, fscA: 1.534, fscB: 1.801
# Epoch [1/50], Step [60/1000], D_A: 0.442, G_A: 1.268, cycle_A: 9.468, D_B: 0.605, G_B: 0.827, cycle_B: 15.346, fscA: 1.364, fscB: 1.927
# Epoch [1/50], Step [80/1000], D_A: 0.590, G_A: 1.159, cycle_A: 7.972, D_B: 0.569, G_B: 1.012, cycle_B: 10.488, fscA: 1.474, fscB: 1.819
# ...
